# %%
import os
os.chdir("/content/drive/MyDrive/25 01 MSc Thesis/")
os.getcwd()
# Out:
# '/content/drive/MyDrive/25 01 MSc Thesis'

# %%
# !python3 'main.py' --train v001.001.001
# Out:
# Hyperparameter set: v001.001.001
# *** Name of the repository:  v001.001.001 ***
# *** Environment parameters:  {'S0': 10, 'B0': 0.001, 'K': 10, 'T': 0.08333, 'mu': 0.1, 'sigma': 0.2, 'r': 0.0, 'epsilon': 0.005, 'alpha0': 0, 'max_alpha': 5, 'Ndt': 100} ***
# *** Algorithm parameters:  {'Ntrajectories': 200, 'Mtransitions': 200, 'Nepochs': 400, 'gamma': 0.99, 'seed': 42, 'Nepochs_V_init': 1500, 'Nepochs_V': 300, 'lr_V': '5e-4', 'batch_V': 200, 'hidden_V': 16, 'layers_V': 4, 'Nepochs_pi': 20, 'lr_pi': '5e-4', 'batch_pi': 200, 'hidden_pi': 16, 'layers_pi': 3} ***
# *** Risk measures parameters:  {'method': 'CVaR'} ***
# *** Run parameters:  None ***
# *** Risk measures:  ['CVaR'] ***
# *** alpha_cvar:  [0.2]
#
# *** Method =  CVaR  ***
#
# 02-26 12:23:53: Training starting...
# --Estimation of V--
#  Epoch = 0,  Loss: 3544.876
#  Epoch = 50,  Loss: 3544.2043
#  Epoch = 100,  Loss: 3540.7437
#  Epoch = 150,  Loss: 3510.3235
#  Epoch = 200,  Loss: 3356.0596
# ...
